# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n�mero de serie del volumen es: DA7E-6F29
#
#  Directorio de c:\Users\gmgar\OneDrive\Documentos\platzi\machine_learning\Proyecto_cdc
#
# 20/04/2022  04:51 p. m.    <DIR>          .
# 20/04/2022  04:51 p. m.    <DIR>          ..
# 20/04/2022  04:51 p. m.           219,664 03_MARZO_2022.xlsx
# 20/04/2022  03:19 p. m.                 0 monterrey.ipynb
# 20/04/2022  03:33 p. m.           208,369 Monterrey_03_22.xlsx
# 20/04/2022  03:22 p. m.    <DIR>          notebooks
# 20/04/2022  03:19 p. m.                 0 requirements.txt
#                4 archivos        428,033 bytes
#                3 dirs  143,076,876,288 bytes libres

# %%
# nos movemos a la carpeta donde estan nuestro archivo de datos
os.chdir('..')

# %%
# %ls

# %%
df_gastos_varios = pd.read_excel('03_MARZO_2022.xlsx', sheet_name='GTOS VARIOS', skiprows=5)
df_gastos_varios['SHEET'] = 'GTOS VARIOS'

# %%
df_gastos_varios.head()
# Out:
#   CVE BEN                       BENEFICIARIO           RFC  \
# 0  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 1  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 2  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 3  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 4  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
#
#                 FACTURA      CONTRATO  \
# 0  FB1179781-183011-215  SAD-638-2021
# 1  FB1190248-183011-220  SAD-638-2021
# 2  FB1203206-183011-224  SAD-638-2021
# 3  FB1210915-183011-228  SAD-638-2021
# 4   FB182281-183011-214  SAD-638-2021
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 1  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 2  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 3  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# ...

# %%
df_contratistas = pd.read_excel('03_MARZO_2022.xlsx', sheet_name='OB.PUBLICA-GTS VARIOS (FDO ESP)', skiprows=5)
df_contratistas['SHEET'] = 'OB.PUBLICA-GTS VARIOS (FDO ESP)'

# %%
df_contratistas.head()
# Out:
#         CVE BEN             BENEFICIARIO           RFC  \
# 0        110036        SEMEX,S.A.DE C.V.  SEM680801193
# 1        110036        SEMEX,S.A.DE C.V.  SEM680801193
# 2  Total 110036                      NaN           NaN
# 3        110150  COMPUMARK, S.A. DE C.V.  CMR9201064P4
# 4  Total 110150                      NaN           NaN
#
#                    FACTURA      CONTRATO  \
# 0        40050-158003-3749  SIV-004-2020
# 1  FACSMX40594-158003-4457  SIV-006-2020
# 2                      NaN           NaN
# 3       A 58560-183011-398      DOC 7414
# 4                      NaN           NaN
#
#                                             CONCEPTO TIPO      FDO-#OP  \
# 0  EST. 13 PARA EL SUMINISTRO Y APLICACION DE PIN...   TR  319000832.0
# 1  SUMINISTRO DE MATERIALES PARA SEÑALAMIENTOS VI...   TR  319000832.0
# 2                                                NaN  NaN          NaN
# 3  SUMINISTRO DE NECESIDADES PARA LA IMPLEMENTACI...   TR  330000018.0
# ...

# %%
df_servicios = pd.read_excel('03_MARZO_2022.xlsx', sheet_name='SERV_PROF', skiprows=5)
df_servicios['SHEET'] = 'SERV_PROF'

# %%
df_servicios.head()
# Out:
#         CVE BEN                                      BENEFICIARIO  \
# 0        115023  PRODUCTIVIDAD INTEGRAL EN SISTEMAS , S.A.DE C.V.
# 1        115023  PRODUCTIVIDAD INTEGRAL EN SISTEMAS , S.A.DE C.V.
# 2        115023  PRODUCTIVIDAD INTEGRAL EN SISTEMAS , S.A.DE C.V.
# 3        115023  PRODUCTIVIDAD INTEGRAL EN SISTEMAS , S.A.DE C.V.
# 4  Total 115023                                               NaN
#
#             RFC          FACTURA      CONTRATO  \
# 0  PIS880822FG2  P138-183011-642  SAD-587-2020
# 1  PIS880822FG2   P87-183011-639  SAD-587-2020
# 2  PIS880822FG2   P88-183011-640  SAD-587-2020
# 3  PIS880822FG2   P95-183011-641  SAD-587-2020
# 4           NaN              NaN           NaN
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  SOPORTE Y ACTUALIZACION DEL GRP-INFOFIN INGRES...   TR  1021933.0
# 1  SOPORTE Y ACTUALIZACION DEL GRP-INFOFIN INGRES...   TR  1021933.0
# 2  SOPORTE Y ACTUALIZACION DEL GRP-INFOFIN INGRES...   TR  1021933.0
# ...

# %%
df_comunicaciones = pd.read_excel('03_MARZO_2022.xlsx', sheet_name='COMUNICACION', skiprows=5)
df_comunicaciones['SHEET'] = 'COMUNICACION'

# %%
df_comunicaciones.head()
# Out:
#         CVE BEN                  BENEFICIARIO           RFC  \
# 0        110820  EDITORA EL SOL, S.A. DE C.V.  ESO851126P67
# 1        110820  EDITORA EL SOL, S.A. DE C.V.  ESO851126P67
# 2        110820  EDITORA EL SOL, S.A. DE C.V.  ESO851126P67
# 3  Total 110820                           NaN           NaN
# 4        115513      EDITORIAL MONTERREY,S.A.  EMO801210AS6
#
#                  FACTURA      CONTRATO  \
# 0      GM3312-183011-781  OEP-311-2022
# 1      GM3313-183011-782  OEP-311-2022
# 2      GM3318-183011-780  OEP-311-2022
# 3                    NaN           NaN
# 4  B - 020951-183011-286  OEP-296-2021
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  DESPLEGADO ( OCTAVO DE PAGINA 13.3CM X 9.8CM) ...   TR  1021994.0
# 1  DESPLEGADO ( OCTAVO DE PAGINA 13.3CM X 9.8CM) ...   TR  1021994.0
# 2  DESPLEGADO ( CUARTO DE PAGINA 26.1CM X 13.4CM)...   TR  1021994.0
# 3                                                NaN  NaN        NaN
# ...

# %%
df_personales = pd.read_excel('03_MARZO_2022.xlsx', sheet_name='SERV PERS', skiprows=5)
df_personales['SHEET'] = 'SERV PERS'

# %%
df_personales.head()
# Out:
#   CVE BEN                     BENEFICIARIO            RFC            FACTURA  \
# 0  203013              ALCALA LARA ARACELY  AALA880303UZ1   44274-183010-335
# 1  203013  ALMAGUER MORENO JAHIR MAGDALENO  AAMJ910719LX5  117714-183010-710
# 2  203013     ALONSO ORDOÑEZ LUBIA YAJAIRA  AOOL861130JT8  119455-183010-412
# 3  203013        ANDRADE LOPEZ JUANA MARIA  AALJ670927DH0  120571-183010-200
# 4  203013       ARRIAGA PEREZ ROCIO JAZMIN  AIPR9204286E1  120583-183010-350
#
#     CONTRATO          CONCEPTO TIPO      FDO-#OP FECHA\nPAGO   IMPORTE  \
# 0  NO APLICA   FINIQUITO 44274   CH  330000103.0  2022-03-07  19686.59
# 1  NO APLICA  FINIQUITO 117714   CH  330000178.0  2022-03-31   3649.96
# 2  NO APLICA  FINIQUITO 119455   CH  330000084.0  2022-03-07   2562.97
# 3  NO APLICA  FINIQUITO 120571   CH  330000113.0  2022-03-10   8638.23
# 4  NO APLICA  FINIQUITO 120583   CH  330000082.0  2022-03-07  23226.91
#
#        SHEET
# 0  SERV PERS
# 1  SERV PERS
# 2  SERV PERS
# 3  SERV PERS
# ...

# %%
df_compras_marzo = pd.concat([df_gastos_varios, df_contratistas, df_servicios, df_comunicaciones, df_personales])

# %%
df_compras_marzo.head()
# Out:
#   CVE BEN                       BENEFICIARIO           RFC  \
# 0  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 1  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 2  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 3  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 4  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
#
#                 FACTURA      CONTRATO  \
# 0  FB1179781-183011-215  SAD-638-2021
# 1  FB1190248-183011-220  SAD-638-2021
# 2  FB1203206-183011-224  SAD-638-2021
# 3  FB1210915-183011-228  SAD-638-2021
# 4   FB182281-183011-214  SAD-638-2021
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 1  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 2  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 3  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# ...

# %%
df_compras_marzo.shape
# Out:
# (2187, 11)

# %%
#Borramos las filas con valores faltantes
df_compras_marzo_com=df_compras_marzo.dropna(how='any')

# %%
df_compras_marzo_com.shape
# Out:
# (1955, 11)

# %%
df_compras_marzo_com.columns
# Out:
# Index(['CVE BEN', 'BENEFICIARIO', 'RFC', 'FACTURA', 'CONTRATO', 'CONCEPTO',
#        'TIPO', 'FDO-#OP', 'FECHA\nPAGO', 'IMPORTE', 'SHEET'],
#       dtype='object')

# %%
#verificamos si los datos faltante aun existen
list(df_compras_marzo_com['CVE BEN'])
# Out:
# [111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111017,
#  111068,
#  111068,
#  112043,
#  112043,
#  112246,
#  112246,
#  112246,
#  112458,
#  112458,
#  112458,
#  112458,
#  112458,
#  112458,
#  112458,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
#  112661,
# ...

# %%
# verificamos el tipo de datos que tenemos en cada columna
df_compras_marzo_com.dtypes
# Out:
# CVE BEN          object
# BENEFICIARIO     object
# RFC              object
# FACTURA          object
# CONTRATO         object
# CONCEPTO         object
# TIPO             object
# FDO-#OP         float64
# FECHA\nPAGO      object
# IMPORTE         float64
# SHEET            object
# dtype: object

# %%
df_compras_marzo_com['FECHA\nPAGO'].head()
# Out:
# 0    2022-03-04 00:00:00
# 1    2022-03-04 00:00:00
# 2    2022-03-04 00:00:00
# 3    2022-03-04 00:00:00
# 4    2022-03-04 00:00:00
# Name: FECHA\nPAGO, dtype: object

# %%
#transformar la columna FECHA\nPAGO a datetime64
df_compras_marzo_com['FECHA\nPAGO'] = df_compras_marzo_com['FECHA\nPAGO'].apply(lambda x: pd.to_datetime(x, format='%Y/%m/%d'))
# Out:
# C:\Users\gmgar\AppData\Local\Temp/ipykernel_9224/1001974071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_compras_marzo_com['FECHA\nPAGO'] = df_compras_marzo_com['FECHA\nPAGO'].apply(lambda x: pd.to_datetime(x, format='%Y/%m/%d'))

# %%
#verificamos el tipo de datos que tenemos
df_compras_marzo_com.dtypes
# Out:
# CVE BEN                 object
# BENEFICIARIO            object
# RFC                     object
# FACTURA                 object
# CONTRATO                object
# CONCEPTO                object
# TIPO                    object
# FDO-#OP                float64
# FECHA\nPAGO     datetime64[ns]
# IMPORTE                float64
# SHEET                   object
# dtype: object

# %%
#verificamos que las fechas sean de un solo mes
df_compras_marzo_com['FECHA\nPAGO'].apply(lambda x: x.month).value_counts()
# Out:
# 3    1939
# 1      16
# Name: FECHA\nPAGO, dtype: int64

# %%
#eliminamos las fechas con valor month != 3
df_compras_marzo_com = df_compras_marzo_com[df_compras_marzo_com['FECHA\nPAGO'].apply(lambda x: x.month) == 3]

# %%
#verificamos nuevamente que esten en un solo mes las fechas
df_compras_marzo_com['FECHA\nPAGO'].apply(lambda x: x.month).value_counts()
# Out:
# 3    1939
# Name: FECHA\nPAGO, dtype: int64

# %%
df_compras_marzo_com.head()
# Out:
#   CVE BEN                       BENEFICIARIO           RFC  \
# 0  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 1  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 2  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 3  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
# 4  111017  PRAXAIR MEXICO S. DE R.L. DE C.V.  PME960701GG0
#
#                 FACTURA      CONTRATO  \
# 0  FB1179781-183011-215  SAD-638-2021
# 1  FB1190248-183011-220  SAD-638-2021
# 2  FB1203206-183011-224  SAD-638-2021
# 3  FB1210915-183011-228  SAD-638-2021
# 4   FB182281-183011-214  SAD-638-2021
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 1  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 2  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# 3  SUMINISTRO DE OXIGENO, GASES MEDICINALES Y ACC...   TR  1021838.0
# ...

# %%
df_compras_marzo_com.shape
# Out:
# (1939, 11)

# %% [markdown]
# Los datos ya estan listos para poder trabajar con ellos de manera sencilla. y lo guadamos en un csv para trabajar con ellos posteriormente.

# %%
# %pwd
# Out:
# 'c:\\Users\\gmgar\\OneDrive\\Documentos\\platzi\\machine_learning\\Proyecto_cdc'

# %%
df_compras_marzo_com.to_csv('./notebooks/data/compras_marzo_2022.csv', index=None)

# %% [markdown]
# .
